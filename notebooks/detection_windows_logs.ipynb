# %%
import pandas as pd

# Load Windows log file
df = pd.read_csv('../data/windows_logs.csv')

# Preview first few rows
df.head()
# Out:
#              timestamp  event_id            event_type username  \
# 0  2025-07-21 11:00:00      4625         Logon Failure    guest
# 1  2025-07-21 11:00:13      4688       Process Created    admin
# 2  2025-07-21 11:00:30      4625         Logon Failure    alice
# 3  2025-07-21 11:00:54      4672  Privilege Escalation    guest
# 4  2025-07-21 11:01:12      4672  Privilege Escalation    guest
#
#              host     logon_type  process_name    privilege_used
# 0  WORKSTATION-01  RemoteDesktop       cmd.exe               NaN
# 1  WORKSTATION-01        Network       cmd.exe               NaN
# 2  FINANCE-LAPTOP    Interactive       cmd.exe               NaN
# 3       SERVER-02  RemoteDesktop    chrome.exe  SeDebugPrivilege
# 4  WORKSTATION-01        Network  explorer.exe  SeDebugPrivilege

# %%
# Fill every row with a placeholder parent process ('explorer.exe') just for detection testing
df['parent_process'] = ['explorer.exe'] * len(df)

# %%
# Lowercase both process name columns for safe comparison
df['process_name'] = df['process_name'].str.lower()
df['parent_process'] = df['parent_process'].str.lower()

# %%
# Define suspicious parent and child processes
suspicious_parents = ['explorer.exe', 'winword.exe', 'outlook.exe']
suspicious_children = ['powershell.exe', 'cmd.exe', 'wscript.exe', 'mshta.exe', 'certutil.exe']

# Filter the DataFrame
suspicious_exec = df[
    (df['parent_process'].isin(suspicious_parents)) &
    (df['process_name'].isin(suspicious_children))
]

# %%
# Show detections if found
if not suspicious_exec.empty:
    print("🚩 Suspicious parent-child process executions detected:")
    display(suspicious_exec[['timestamp', 'parent_process', 'process_name', 'username', 'host']])
else:
    print("✅ No suspicious parent-child executions detected in this dataset.")
# Out:
# 🚩 Suspicious parent-child process executions detected:
#               timestamp parent_process    process_name username  \
# 0   2025-07-21 11:00:00   explorer.exe         cmd.exe    guest
# 1   2025-07-21 11:00:13   explorer.exe         cmd.exe    admin
# 2   2025-07-21 11:00:30   explorer.exe         cmd.exe    alice
# 7   2025-07-21 11:03:30   explorer.exe         cmd.exe    guest
# 13  2025-07-21 11:02:49   explorer.exe  powershell.exe  charlie
# 16  2025-07-21 11:03:28   explorer.exe         cmd.exe    guest
# 22  2025-07-21 11:10:16   explorer.exe         cmd.exe    alice
# 29  2025-07-21 11:13:03   explorer.exe  powershell.exe    admin
# 33  2025-07-21 11:08:15   explorer.exe  powershell.exe    guest
# 38  2025-07-21 11:06:20   explorer.exe  powershell.exe    admin
# 49  2025-07-21 11:13:04   explorer.exe  powershell.exe    alice
# 54  2025-07-21 11:24:18   explorer.exe  powershell.exe    guest
# 56  2025-07-21 11:14:00   explorer.exe  powershell.exe  charlie
# 60  2025-07-21 11:27:00   explorer.exe         cmd.exe    guest
# 71  2025-07-21 11:23:40   explorer.exe  powershell.exe    alice
# 74  2025-07-21 11:35:46   explorer.exe  powershell.exe    alice
# 79  2025-07-21 11:30:17   explorer.exe         cmd.exe    admin
# 81  2025-07-21 11:17:33   explorer.exe  powershell.exe      bob
# 87  2025-07-21 11:42:03   explorer.exe  powershell.exe      bob
# 90  2025-07-21 11:27:00   explorer.exe  powershell.exe    admin
# 91  2025-07-21 11:25:47   explorer.exe  powershell.exe    admin
# 98  2025-07-21 11:31:02   explorer.exe  powershell.exe      bob
#
#               host
# 0   WORKSTATION-01
# 1   WORKSTATION-01
# 2   FINANCE-LAPTOP
# 7   FINANCE-LAPTOP
# 13  FINANCE-LAPTOP
# 16  WORKSTATION-01
# 22  WORKSTATION-01
# 29  FINANCE-LAPTOP
# 33       SERVER-02
# 38  WORKSTATION-01
# 49       SERVER-02
# 54  FINANCE-LAPTOP
# 56  FINANCE-LAPTOP
# 60           HR-PC
# 71  FINANCE-LAPTOP
# 74       SERVER-02
# 79           HR-PC
# 81  WORKSTATION-01
# 87           HR-PC
# 90  WORKSTATION-01
# 91  WORKSTATION-01
# 98  WORKSTATION-01

# %%
# Filter only failed logon attempts (event ID 4625)
failed_logins = df[df['event_id'] == 4625].copy()
failed_logins.head()
# Out:
#               timestamp  event_id     event_type username            host  \
# 0   2025-07-21 11:00:00      4625  Logon Failure    guest  WORKSTATION-01
# 2   2025-07-21 11:00:30      4625  Logon Failure    alice  FINANCE-LAPTOP
# 8   2025-07-21 11:01:28      4625  Logon Failure    alice           HR-PC
# 10  2025-07-21 11:02:20      4625  Logon Failure      bob  WORKSTATION-01
# 13  2025-07-21 11:02:49      4625  Logon Failure  charlie  FINANCE-LAPTOP
#
#        logon_type    process_name privilege_used
# 0   RemoteDesktop         cmd.exe            NaN
# 2     Interactive         cmd.exe            NaN
# 8   RemoteDesktop    explorer.exe            NaN
# 10        Network    mimikatz.exe            NaN
# 13    Interactive  powershell.exe            NaN

# %%
import pandas as pd
from datetime import timedelta

# Load the dataset
df = pd.read_csv('../data/windows_logs.csv')

# Filter only failed login attempts (Event ID 4625)
failed_logins = df[df['event_id'] == 4625].copy()

# Convert timestamp column to datetime and sort by time
failed_logins['timestamp'] = pd.to_datetime(failed_logins['timestamp'])
failed_logins = failed_logins.sort_values(by='timestamp')

# Detection parameters
threshold_attempts = 5
time_window = timedelta(minutes=2)
suspicious_windows = []

# %%
# Group by host and look for repeated failed logins within 2-minute windows
for host, group in failed_logins.groupby('host'):
    group = group.sort_values('timestamp').reset_index(drop=True)
    
    for i in range(len(group)):
        window_start = group.loc[i, 'timestamp']
        window_end = window_start + time_window
        
        window_group = group[(group['timestamp'] >= window_start) & (group['timestamp'] <= window_end)]
        
        if len(window_group) >= threshold_attempts:
            suspicious_windows.append(window_group)
            break

# %%
# Display suspicious failed login clusters
if suspicious_windows:
    result_df = pd.concat(suspicious_windows).drop_duplicates()
    print("🚩 Multiple failed login attempts detected from same host:")
    display(result_df[['timestamp', 'event_type', 'username', 'host']])
else:
    print("✅ No suspicious login patterns detected in this dataset.")
# Out:
# ✅ No suspicious login patterns detected in this dataset.

# %%
# Rule 3 – Detect suspicious use of privilege escalation (Event ID 4672)

# Filter only privileged logon events
priv_escalation = df[df['event_id'] == 4672].copy()

# Convert timestamp
priv_escalation['timestamp'] = pd.to_datetime(priv_escalation['timestamp'])

# Define suspicious usernames and hostnames (can customise)
suspicious_users = ['guest', 'test', 'admin', 'svc_account']
suspicious_hosts = ['FINANCE-LAPTOP', 'DEV-01', 'HR-PC']

# Apply filters
suspicious_events = priv_escalation[
    (priv_escalation['username'].str.lower().isin(suspicious_users)) |
    (priv_escalation['host'].isin(suspicious_hosts))
]

# Display the results
if not suspicious_events.empty:
    print("🚩 Suspicious privilege escalation events detected:")
    display(suspicious_events[['timestamp', 'event_type', 'username', 'host', 'privilege_used']])
else:
    print("✅ No suspicious privilege escalation detected.")
# Out:
# 🚩 Suspicious privilege escalation events detected:
#              timestamp            event_type username            host  \
# 3  2025-07-21 11:00:54  Privilege Escalation    guest       SERVER-02
# 4  2025-07-21 11:01:12  Privilege Escalation    guest  WORKSTATION-01
# 9  2025-07-21 11:03:27  Privilege Escalation    guest  WORKSTATION-01
# 16 2025-07-21 11:03:28  Privilege Escalation    guest  WORKSTATION-01
# 20 2025-07-21 11:07:40  Privilege Escalation    guest  WORKSTATION-01
# 28 2025-07-21 11:13:32  Privilege Escalation    guest           HR-PC
# 37 2025-07-21 11:18:30  Privilege Escalation    guest  FINANCE-LAPTOP
# 38 2025-07-21 11:06:20  Privilege Escalation    admin  WORKSTATION-01
# 45 2025-07-21 11:17:15  Privilege Escalation      bob           HR-PC
# 50 2025-07-21 11:21:40  Privilege Escalation    guest  FINANCE-LAPTOP
# 57 2025-07-21 11:15:12  Privilege Escalation    alice  FINANCE-LAPTOP
# 60 2025-07-21 11:27:00  Privilege Escalation    guest           HR-PC
# 65 2025-07-21 11:23:50  Privilege Escalation    admin           HR-PC
# 66 2025-07-21 11:20:54  Privilege Escalation    alice           HR-PC
# 70 2025-07-21 11:33:50  Privilege Escalation    admin       SERVER-02
# 75 2025-07-21 11:21:15  Privilege Escalation    guest           HR-PC
# 93 2025-07-21 11:37:12  Privilege Escalation    guest  WORKSTATION-01
# 96 2025-07-21 11:32:00  Privilege Escalation    guest  FINANCE-LAPTOP
#
#       privilege_used
# 3   SeDebugPrivilege
# 4   SeDebugPrivilege
# 9   SeDebugPrivilege
# 16  SeDebugPrivilege
# 20  SeDebugPrivilege
# 28  SeDebugPrivilege
# 37  SeDebugPrivilege
# 38  SeDebugPrivilege
# 45  SeDebugPrivilege
# 50  SeDebugPrivilege
# 57  SeDebugPrivilege
# 60  SeDebugPrivilege
# 65  SeDebugPrivilege
# 66  SeDebugPrivilege
# 70  SeDebugPrivilege
# 75  SeDebugPrivilege
# 93  SeDebugPrivilege
# 96  SeDebugPrivilege
